# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8392\2990454276.py in <module>
#       3 a = 10
#       4 b = "5"
# ----> 5 print(a + b)
#       6
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Can't add string and interger
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
# As per function syntax colon is missing
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
# The list values ranging from 0 to 3. So out of range error will be thrown
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
# As per syntax, print statement should be within parentheses
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
# Will get zero division error, as division by zero is not allowed

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
name = "Alice"
age = 25
print("Name: ",name,"\nAge: ",age)
# Out:
# Name:  Alice
# Age:  25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#As per syntax
# range (start,stop,step)
# Issue is, given range is increasing, but it was aske to count decreasing. So it will not execute
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
# = is a assignment operator
# == is a comparison operator
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
# As per syntax fucntion should end with colon (:)
def greet(name):
    print("Hello, " + name)
greet("Vikram")
# Out:
# Hello, Vikram
